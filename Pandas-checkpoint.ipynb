# %%
#importing module
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')

# %%
#define a dictionary 
XYZ_web={'Day':[1,2,3,4,5,6],'Visitors':[1000,700,6000,1000,400,350],'Bounce_Rate':[20,20,23,15,10,34]}

# %%
#Convert the dictionary into dataframe
df=pd.DataFrame(XYZ_web)

# %%
df
# Out:
#    Day  Visitors  Bounce_Rate
# 0    1      1000           20
# 1    2       700           20
# 2    3      6000           23
# 3    4      1000           15
# 4    5       400           10
# 5    6       350           34

# %% [markdown]
# # Slicing

# %%
#if you want to print the first two rows
print(df.head(2))
# Out:
#    Day  Visitors  Bounce_Rate
# 0    1      1000           20
# 1    2       700           20

# %%
#if you want to print the last two rows
print(df.tail(2))
# Out:
#    Day  Visitors  Bounce_Rate
# 4    5       400           10
# 5    6       350           34

# %% [markdown]
# # Merging

# %%
#define 3 dataframe
df1=pd.DataFrame({'HPI':[80,90,70,60],'Int_rate':[2,1,2,3],'IND_GDP':[50,45,45,67]},index=[2001,2002,2003,2004])
df2=pd.DataFrame({'HPI':[80,90,70,60],'Int_rate':[2,1,2,3],'IND_GDP':[50,45,45,67]},index=[2005,2006,2007,2008])
merge=pd.merge(df1,df2,on='HPI')

# %%
print(merge)
# Out:
#    HPI  Int_rate_x  IND_GDP_x  Int_rate_y  IND_GDP_y
# 0   80           2         50           2         50
# 1   90           1         45           1         45
# 2   70           2         45           2         45
# 3   60           3         67           3         67

# %% [markdown]
# # Joining

# %%
df1=pd.DataFrame({'Int_rate':[2,1,2,3],'IND_GDP':[50,45,45,67]},index=[2001,2002,2003,2004])
df2=pd.DataFrame({'Low_Tier_HPI':[50,45,45,67],'Unemployment':[1,3,5,6]},index=[2001,2003,2004,2004])

# %%
joined=df1.join(df2)
print(joined)
# Out:
#       Int_rate  IND_GDP  Low_Tier_HPI  Unemployment
# 2001         2       50          50.0           1.0
# 2002         1       45           NaN           NaN
# 2003         2       45          45.0           3.0
# 2004         3       67          45.0           5.0
# 2004         3       67          67.0           6.0

# %% [markdown]
# # Changing index and column headers

# %%
df=pd.DataFrame({'Day':[1,2,3,4],'Visitors':[200,100,230,300],'Bounce_Rate':[20,45,60,10]})

# %%
df.set_index('Day',inplace=True)

# %%
df
# Out:
#      Visitors  Bounce_Rate
# Day
# 1         200           20
# 2         100           45
# 3         230           60
# 4         300           10

# %%
df=pd.DataFrame({'Day':[1,2,3,4],'Visitors':[200,100,230,300],'Bounce_Rate':[20,45,60,10]})

# %%
df.set_index('Day',inplace=True)

# %%
df.plot()
plt.show()

# %%
#change the column header from visitors to users
df=pd.DataFrame({'Day':[1,2,3,4],'Visitors':[200,100,230,300],'Bounce_Rate':[20,45,60,10]})

# %%
df=df.rename(columns={'Visitors':'Users'})

# %%
df
# Out:
#    Day  Users  Bounce_Rate
# 0    1    200           20
# 1    2    100           45
# 2    3    230           60
# 3    4    300           10

# %% [markdown]
# # Concatenation

# %%
df1=pd.DataFrame({'HPI':[80,85,88,85],'Int_rate':[2,3,2,2],'US_GDP_Thousands':[50,55,65,55]},index=[2001,2002,2003,2004])
df2=pd.DataFrame({'HPI':[80,85,88,85],'Int_rate':[2,3,2,2],'US_GDP_Thousands':[50,55,65,55]},index=[2005,2006,2007,2008])
concat=pd.concat([df1,df2])

# %%
print(concat)
# Out:
#       HPI  Int_rate  US_GDP_Thousands
# 2001   80         2                50
# 2002   85         3                55
# 2003   88         2                65
# 2004   85         2                55
# 2005   80         2                50
# 2006   85         3                55
# 2007   88         2                65
# 2008   85         2                55

# %% [markdown]
# # Data Munging

# %% [markdown]
# Data Munging means convert a particular form of data into different format.

# %%
country=pd.read_csv('Salary_Data.csv')

# %%
country.to_html('Salary_Data.html')

# %%
import numpy as np

# %%
dict1={
    'name':['harry','rohan','sklif','shubh'],
    'marks':[92,34,24,17],
    'city':['rampur','kolkata','bareilly','antarctica']
}

# %%
df=pd.DataFrame(dict1)

# %%
df
# Out:
#     name  marks        city
# 0  harry     92      rampur
# 1  rohan     34     kolkata
# 2  sklif     24    bareilly
# 3  shubh     17  antarctica

# %%
df.to_csv('friends.csv')

# %%
df.to_csv('friends_index_false.csv',index=False)

# %%
df.head(2)
# Out:
#     name  marks     city
# 0  harry     92   rampur
# 1  rohan     34  kolkata

# %%
df.tail(2)
# Out:
#     name  marks        city
# 2  sklif     24    bareilly
# 3  shubh     17  antarctica

# %%
df.describe()
# Out:
#           marks
# count   4.00000
# mean   41.75000
# std    34.21866
# min    17.00000
# 25%    22.25000
# 50%    29.00000
# 75%    48.50000
# max    92.00000

# %%
harry={
    'train_no':[12322,12534,125654,564523],
    'speed':[34,123,67,87],
    'city':['rampur','kolkata','bareilly','antarctica']
}

# %%
df1=pd.DataFrame(harry)

# %%
df1
# Out:
#    train_no  speed        city
# 0     12322     34      rampur
# 1     12534    123     kolkata
# 2    125654     67    bareilly
# 3    564523     87  antarctica

# %%
df1['speed']
# Out:
# 0     34
# 1    123
# 2     67
# 3     87
# Name: speed, dtype: int64

# %%
df1['speed'][0]
# Out:
# 34

# %%
df1['speed'][0]=50
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
df1
# Out:
#    train_no  speed        city
# 0     12322     50      rampur
# 1     12534    123     kolkata
# 2    125654     67    bareilly
# 3    564523     87  antarctica

# %%
df1.to_csv('df1.csv')

# %%
df1.index=['first','second','third','fourth']

# %%
df1
# Out:
#         train_no  speed        city
# first      12322     50      rampur
# second     12534    123     kolkata
# third     125654     67    bareilly
# fourth    564523     87  antarctica

# %% [markdown]
# # Series

# %%
ser=pd.Series(np.random.rand)

# %%
ser
# Out:
# 0    <built-in method rand of mtrand.RandomState ob...
# dtype: object

# %%
type(ser)
# Out:
# pandas.core.series.Series

# %%
ser=pd.Series(np.random.rand(34))

# %%
ser
# Out:
# 0     0.255603
# 1     0.511602
# 2     0.903699
# 3     0.075843
# 4     0.812120
# 5     0.671631
# 6     0.968420
# 7     0.523473
# 8     0.549035
# 9     0.287285
# 10    0.920034
# 11    0.083367
# 12    0.611413
# 13    0.055978
# 14    0.864044
# 15    0.985928
# 16    0.768916
# 17    0.900373
# 18    0.300006
# 19    0.471117
# 20    0.843410
# 21    0.938398
# 22    0.840059
# 23    0.329859
# 24    0.984277
# 25    0.017727
# 26    0.589641
# 27    0.064412
# 28    0.952642
# 29    0.031271
# 30    0.078988
# 31    0.507454
# 32    0.169081
# 33    0.756293
# dtype: float64

# %% [markdown]
# # DataFrame

# %%
newdf=pd.DataFrame(np.random.rand(334,5),index=np.arange(334))

# %%
newdf
# Out:
#             0         1         2         3         4
# 0    0.628725  0.093954  0.135653  0.565617  0.125108
# 1    0.701349  0.307845  0.386040  0.845240  0.372377
# 2    0.844590  0.538599  0.445349  0.078097  0.274500
# 3    0.030373  0.859301  0.467462  0.206677  0.150861
# 4    0.239909  0.414866  0.037620  0.646305  0.960047
# 5    0.931789  0.366941  0.412888  0.181437  0.379102
# 6    0.487305  0.613797  0.841114  0.298662  0.787115
# 7    0.968238  0.179791  0.707579  0.725102  0.817489
# 8    0.594341  0.902612  0.858201  0.773216  0.116302
# 9    0.716185  0.049973  0.951556  0.319198  0.266230
# 10   0.244931  0.594954  0.268317  0.726640  0.485623
# 11   0.069185  0.967402  0.605085  0.846946  0.993529
# 12   0.743638  0.645206  0.314732  0.807605  0.107186
# 13   0.550253  0.461431  0.314323  0.997771  0.627360
# 14   0.911637  0.654526  0.889148  0.586517  0.360213
# 15   0.475030  0.611837  0.725653  0.050131  0.253521
# ...

# %%
newdf.head()
# Out:
#           0         1         2         3         4
# 0  0